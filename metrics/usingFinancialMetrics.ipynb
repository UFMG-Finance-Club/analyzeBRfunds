# %%
import pandas as pd
import FinancialMetrics

# %%
(
    FinancialMetrics
    .Metrics(inpath="/home/marcel/outros/finance-fundos/DownloadedData/201703.csv")
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/marcel/outros/ckrepo/analyzeBRfunds/metrics/usingFinancialMetrics.ipynb Cell 2' in <cell line: 2>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/marcel/outros/ckrepo/analyzeBRfunds/metrics/usingFinancialMetrics.ipynb#ch0000005vscode-remote?line=0'>1</a> (
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/marcel/outros/ckrepo/analyzeBRfunds/metrics/usingFinancialMetrics.ipynb#ch0000005vscode-remote?line=1'>2</a>     FinancialMetrics
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/marcel/outros/ckrepo/analyzeBRfunds/metrics/usingFinancialMetrics.ipynb#ch0000005vscode-remote?line=2'>3</a>     .Metrics(inpath="/home/marcel/outros/finance-fundos/DownloadedData/201703.csv")
# ...
